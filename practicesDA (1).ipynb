# %%
import pandas as pd
df=pd.read_excel("C:/Users/PC/Downloads/us_youtube_trending.xlsx")
df.head(10)
# Out:
#       video_id trending_date          channel_title  category_id  \
# 0  2kyS6SvSYSE    2017-11-14           CaseyNeistat           22
# 1  1ZAPwfrtAFY    2017-11-14        LastWeekTonight           24
# 2  5qpjK5DgCt4    2017-11-14           Rudy Mancuso           23
# 3  puqaWrEC7tY    2017-11-14  Good Mythical Morning           24
# 4  d380meD0W0M    2017-11-14               nigahiga           24
# 5  gHZ1Qz0KiKM    2017-11-14               iJustine           28
# 6  39idVpFF7NQ    2017-11-14    Saturday Night Live           24
# 7  nc99ccSXST0    2017-11-14     CrazyRussianHacker           28
# 8  jr9QtXwC9vc    2017-11-14       20th Century Fox            1
# 9  TUmyygCMMGA    2017-11-14                    Vox           25
#
#                publish_time    views   likes  dislikes  comment_count  \
# 0  2017-11-13T17:13:01.000Z   748374   57527      2966          15954
# 1  2017-11-13T07:30:00.000Z  2418783   97185      6146          12703
# ...

# %%
task1=df.dropna(subset=['video_id'])
task1
# Out:
#          video_id trending_date          channel_title  category_id  \
# 0     2kyS6SvSYSE    2017-11-14           CaseyNeistat           22
# 1     1ZAPwfrtAFY    2017-11-14        LastWeekTonight           24
# 2     5qpjK5DgCt4    2017-11-14           Rudy Mancuso           23
# 3     puqaWrEC7tY    2017-11-14  Good Mythical Morning           24
# 4     d380meD0W0M    2017-11-14               nigahiga           24
# ...           ...           ...                    ...          ...
# 9876  OVnxBcS5qWo    2018-02-01               Nintendo           20
# 9877  ltzy5vRmN8Q    2018-02-01            BURGER KING           24
# 9878  NEmFS50lsTw    2018-02-01          SKITTLESbrand           24
# 9879  NZ0ImXT1FZk    2018-02-01       Brave Wilderness           15
# 9880  t3z_pdr6z8w    2018-02-01            Jackie Aina           26
#
#                   publish_time    views   likes  dislikes  comment_count  \
# 0     2017-11-13T17:13:01.000Z   748374   57527      2966          15954
# ...

# %%
task2=df[df.duplicated(['video_id'])]
task2
# Out:
#          video_id trending_date     channel_title  category_id  \
# 550   9KIP-Ncp2jU    2017-11-16           12 News           22
# 9087  PluaPvhkIMU    2017-12-29  20th Century Fox            1
# 4299  ykHeGtN4m94    2017-12-05  20th Century Fox            1
# 4522  ykHeGtN4m94    2017-12-06  20th Century Fox            1
# 5595  aj8mN_7Apcw    2017-12-12  20th Century Fox            1
# ...           ...           ...               ...          ...
# 7592  NePlddZpNKs    2017-12-22          wdwmagic           19
# 7130  NePlddZpNKs    2017-12-20          wdwmagic           19
# 6921  NePlddZpNKs    2017-12-19          wdwmagic           19
# 7821  NePlddZpNKs    2017-12-23          wdwmagic           19
# 8887  NePlddZpNKs    2017-12-28          wdwmagic           19
#
#                   publish_time    views  likes  dislikes  comment_count  \
# 550   2017-11-11T01:03:01.000Z    92327    182        45              0
# ...

# %%
task4_1=df.dtypes
task4_2a=pd.to_datetime(df['trending_date'])
task4_2b=pd.to_datetime(df['publish_time'])
task4_2b
# Out:
# 0      2017-11-13 17:13:01+00:00
# 1      2017-11-13 07:30:00+00:00
# 2      2017-11-12 19:05:24+00:00
# 3      2017-11-13 11:00:04+00:00
# 4      2017-11-12 18:01:41+00:00
#                   ...
# 9876   2018-01-25 21:25:58+00:00
# 9877   2018-01-24 14:08:29+00:00
# 9878   2018-01-24 15:31:57+00:00
# 9879   2018-01-24 12:00:02+00:00
# 9880   2018-01-25 05:05:42+00:00
# Name: publish_time, Length: 9881, dtype: datetime64[ns, UTC]

# %%
task3=df.drop_duplicates(subset=['video_id'],keep='last')
task3
# Out:
#          video_id trending_date           channel_title  category_id  \
# 10    9wRQljFNDW8    2017-11-14                     NFL           17
# 36    Om_zGhJLZ5U    2017-11-14          Screen Junkies            1
# 41    goP4Z5wyOlM    2017-11-14                BBC News           25
# 54    8NHA23f7LvU    2017-11-14  The Graham Norton Show           24
# 75    IE-xepGLVt8    2017-11-14             Mayo Clinic           28
# ...           ...           ...                     ...          ...
# 9876  OVnxBcS5qWo    2018-02-01                Nintendo           20
# 9877  ltzy5vRmN8Q    2018-02-01             BURGER KING           24
# 9878  NEmFS50lsTw    2018-02-01           SKITTLESbrand           24
# 9879  NZ0ImXT1FZk    2018-02-01        Brave Wilderness           15
# 9880  t3z_pdr6z8w    2018-02-01             Jackie Aina           26
#
#                   publish_time    views   likes  dislikes  comment_count  \
# ...

# %%
task6_1 = df.sort_values(by=['channel_title'], ascending=True)
task6_2 = task6_1.sort_values(by=['views'], ascending=False)
task6_2
# Out:
#          video_id trending_date      channel_title  category_id  \
# 6103  FlsCjmMhFmw    2017-12-14  YouTube Spotlight           24
# 5860  FlsCjmMhFmw    2017-12-13  YouTube Spotlight           24
# 5629  FlsCjmMhFmw    2017-12-12  YouTube Spotlight           24
# 5386  FlsCjmMhFmw    2017-12-11  YouTube Spotlight           24
# 2558  TyHvyGVs42U    2017-11-26      LuisFonsiVEVO           10
# ...           ...           ...                ...          ...
# 42    NZFhMSgbKKM    2017-11-14       Ben Rohrbach           17
# 1102  g3VgrgV3kFk    2017-11-19        Single Shot           17
# 159   qg0GdM60syI    2017-11-14    90s Commercials           27
# 769           NaN    2017-11-17      GoDucksdotcom           17
# 541           NaN    2017-11-16      GoDucksdotcom           17
#
#                   publish_time      views    likes  dislikes  comment_count  \
# 6103  2017-12-06T17:58:51.000Z  149376127  3093544   1643059         810698
# ...

# %%
task7= df[(df.views > 10000000) & (df.likes > 100000)]
task7_2 = task7.sort_values(by=['comment_count'], ascending=False).head(5)
task7_2
# Out:
#          video_id trending_date      channel_title  category_id  \
# 4961  FlsCjmMhFmw    2017-12-09  YouTube Spotlight           24
# 5860  FlsCjmMhFmw    2017-12-13  YouTube Spotlight           24
# 6103  FlsCjmMhFmw    2017-12-14  YouTube Spotlight           24
# 5629  FlsCjmMhFmw    2017-12-12  YouTube Spotlight           24
# 5386  FlsCjmMhFmw    2017-12-11  YouTube Spotlight           24
#
#                   publish_time      views    likes  dislikes  comment_count  \
# 4961  2017-12-06T17:58:51.000Z   75969469  2251797   1127798         827755
# 5860  2017-12-06T17:58:51.000Z  137843120  3014471   1602383         817582
# 6103  2017-12-06T17:58:51.000Z  149376127  3093544   1643059         810698
# 5629  2017-12-06T17:58:51.000Z  125432237  2912702   1545015         807558
# 5386  2017-12-06T17:58:51.000Z  113874632  2811215   1470383         787174
#
#       comments_disabled  ratings_disabled
# 4961              False             False
# ...

# %%
task8=df[(df['comments_disabled']==True) & (df['ratings_disabled']==True)].groupby(by=["category_id","channel_title"]).count()
task8
# Out:
#                                           video_id  trending_date  \
# category_id channel_title
# 1           hudsonunionsociety                   7              7
# 10          Snapchat                             8              8
# 17          Alpha Entertainment                  1              1
#             Pac-12 Networks                      6              6
# 24          HARRY                                4              4
# 25          American Bridge 21st Century         1              1
# 28          Slooh                                1              1
# 29          Define American                      4              4
#
#                                           publish_time  views  likes  \
# category_id channel_title
# 1           hudsonunionsociety                       7      7      7
# 10          Snapchat                                 8      8      8
# 17          Alpha Entertainment                      1      1      1
# ...

# %%
task5=df.describe()
task5
# Out:
#        category_id         views         likes      dislikes  comment_count
# count  9881.000000  9.881000e+03  9.881000e+03  9.881000e+03    9881.000000
# mean     19.970347  1.288900e+06  4.746089e+04  3.066993e+03    5817.316668
# std       7.544083  5.110157e+06  1.705132e+05  3.889208e+04   30624.868658
# min       1.000000  6.870000e+02  0.000000e+00  0.000000e+00       0.000000
# 25%      17.000000  8.960900e+04  2.031000e+03  8.500000e+01     273.000000
# 50%      24.000000  3.116210e+05  9.003000e+03  3.250000e+02    1031.000000
# 75%      25.000000  1.001367e+06  2.942500e+04  1.131000e+03    3377.000000
# max      43.000000  1.493761e+08  3.093544e+06  1.643059e+06  827755.000000

# %%
task5_1 = df.corr()
task5_1
# Out:
#                    category_id     views     likes  dislikes  comment_count  \
# category_id           1.000000 -0.068531 -0.092913  0.002402      -0.022163
# views                -0.068531  1.000000  0.880433  0.673456       0.775262
# likes                -0.092913  0.880433  1.000000  0.530022       0.850243
# dislikes              0.002402  0.673456  0.530022  1.000000       0.756843
# comment_count        -0.022163  0.775262  0.850243  0.756843       1.000000
# comments_disabled     0.053657 -0.017610 -0.030216 -0.000411      -0.026670
# ratings_disabled     -0.052243 -0.010271 -0.019651 -0.005567      -0.012661
#
#                    comments_disabled  ratings_disabled
# category_id                 0.053657         -0.052243
# views                      -0.017610         -0.010271
# likes                      -0.030216         -0.019651
# dislikes                   -0.000411         -0.005567
# comment_count              -0.026670         -0.012661
# ...
